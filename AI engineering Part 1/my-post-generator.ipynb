# %% [markdown]
# ### Step 1: Import Libraraies & API Keys

# %%
import os
from openai import OpenAI
from dotenv import load_dotenv
from IPython.display import display, Markdown

load_dotenv()

OpenAI_API_KEY = os.getenv("OPENAI_API_KEY")

if  OpenAI_API_KEY is None:
    raise Exception("OPENAI_API_KEY is missing")

# %% [markdown]
# ### Step 2:  Searching the Web

# %%
client = OpenAI()

completion = client.chat.completions.create(
    model="gpt-4o-mini-search-preview",
    messages=[
        {"role": "user", "content": "what is todays date? Tell me the 3 top stories in AI news in the past week and each story should be from a separate source and date. Include dates "}
    ]
)
max_tokens = 500

# %%
search_results = completion.choices[0].message.content
display(Markdown(search_results))
# Out:
# As of today, Monday, July 13, 2026, here are three significant AI news stories from the past week, each from a different source and date:
#
# **1. Apple Sues OpenAI for Trade Secret Theft**
#
# *Date: July 11, 2026*
#
# Apple filed a federal lawsuit in Northern California alleging that OpenAI systematically solicited over 400 former Apple employees who allegedly stole confidential data about unreleased hardware and software. This is the first major legal battle of the "AI talent war" era and could force frontier labs to dramatically change their hiring practices. ([champaignmagazine.com](https://champaignmagazine.com/2026/07/12/ai-by-ai-weekly-top-5-july-6-12-2026/?utm_source=openai))
#
# **2. Meta's AI Revenue Plan**
#
# *Date: July 9, 2026*
#
# ...

# %% [markdown]
# ### Summarise and Write socail meedia post

# %%
system_message = """"
You are helpful assistant who can create amazing linkedin posts about AI based on the text you are provided with.
make the posts engaging and interesting.
"""
prompt = f"""
The following text contains top 3 news stories about AI from past week.
Now please write my linkedin post based on this information.

{search_results}

"""

completion = client.chat.completions.create(
    model="gpt-4o-mini",
    messages=[
        {"role": "system", "content": system_message},
        {"role": "user", "content": prompt}
    ],
    max_tokens=500,
    temperature=0.7,
)

chat_response = completion.choices[0].message.content

# %%
#print(chat_response)
display(Markdown(chat_response))
# Out:
# 🚀 **This Week in AI: Major Developments Shaping the Future!** 🌍
#
# As we dive into the week of July 13, 2026, the world of artificial intelligence continues to evolve at lightning speed. Here are three significant stories that are making waves:
#
# 1️⃣ **Apple vs. OpenAI: The Trade Secret Showdown**
# In a groundbreaking legal move, Apple has filed a lawsuit against OpenAI, accusing the company of systematically soliciting over 400 former Apple employees and stealing confidential data on unreleased hardware and software. This marks the beginning of what many are calling the "AI talent war," potentially reshaping hiring practices across frontier labs. The outcome could set a precedent for how companies protect their intellectual property in this competitive landscape. ([Read more here](https://champaignmagazine.com/2026/07/12/ai-by-ai-weekly-top-5-july-6-12-2026/?utm_source=openai))
#
# 2️⃣ **Meta’s Bold AI Revenue Strategy**
# ...
