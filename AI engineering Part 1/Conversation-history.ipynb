# %% [markdown]
# ### Step 1: Import Libraries and Load the environment Variables

# %%
import os
from openai import OpenAI
from dotenv import load_dotenv
from IPython.display import Markdown, display
load_dotenv

OPENAI_API_KEY=os.getenv("OPENAI_API_KEY")

if OPENAI_API_KEY is None:
    raise Exception("API Key is missing")
else:
    print(OPENAI_API_KEY[:8])

cleint = OpenAI()
# Out:
# sk-proj-

# %% [markdown]
# ### Step 2: Call the API

# %%
response = cleint.chat.completions.create(
    model="gpt-4o-mini",    
    messages=[
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": "Next week Im travel to Dubai"}
    ]   
)
reply = response.choices[0].message.content
display(Markdown(reply))
# Out:
# That sounds exciting! Dubai is a vibrant city with plenty to see and do. Whether you're interested in shopping, sightseeing, or experiencing the local culture, there's something for everyone. Here are some tips and highlights for your trip:
#
# ### Popular Attractions:
# 1. **Burj Khalifa**: Visit the tallest building in the world for stunning views of the city.
# 2. **Dubai Mall**: One of the largest shopping malls, featuring an aquarium, an ice rink, and numerous dining options.
# 3. **Dubai Marina**: A beautiful area to stroll around, dine, and take a boat ride.
# 4. **Palm Jumeirah**: An artificial island with luxury resorts, beaches, and dining.
# 5. **Dubai Desert Safari**: Experience dune bashing, camel rides, and traditional Bedouin culture in the desert.
# 6. **Dubai Creek and the Gold Souk**: Explore the historic part of the city and browse for gold and spices.
#
# ### Cultural Experiences:
# ...

# %%
response = cleint.chat.completions.create(
    model="gpt-4o-mini",    
    messages=[
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": "Where am I trarveling to next week?"}
    ]   
)
reply = response.choices[0].message.content
display(Markdown(reply))
# Out:
# I'm sorry, but I don't have access to your personal information or travel plans. If you provide me with details or context about your trip, I might be able to help you with travel tips or suggestions!

# %% [markdown]
# ### In theroy....Manual

# %%
messges=[
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": "Next week Im travel to Dubai"},
        {"role": "assistant", "content": "That sounds exciting! Dubai has a lot to offer in terms of attractions, culture, and activities. Do you have any specific plans or places you want to visit while you're there? I can help with recommendations on things to do, places to eat, and tips for your trip!"},
        {"role": "user", "content": "where am I trarveling to next week?"}
]

response = cleint.chat.completions.create(
    model="gpt-4o-mini",   
    messages=messges)


reply = response.choices[0].message.content
display(Markdown(reply))
# Out:
# You mentioned earlier that you are traveling to Dubai next week. If you need more information or recommendations about your trip to Dubai, feel free to ask!

# %% [markdown]
# ### In theroy....NOT Manual

# %%
messages=[     {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": "Next week Im travel to Dubai"}
]

response = cleint.chat.completions.create(
    model="gpt-4.1-mini",    
    messages=messages
    
)


reply = response.choices[0].message.content
messages.append({"role": "assistant", "content": reply})
print(messages)
#display(Markdown(reply))
# Out:
# [{'role': 'system', 'content': 'You are a helpful assistant.'}, {'role': 'user', 'content': 'Next week Im travel to Dubai'}, {'role': 'assistant', 'content': 'That sounds exciting! Do you need any tips or information about traveling to Dubai? I can help with recommendations on places to visit, things to do, weather, or travel advice.'}]

# %%
from pprint import pprint
pprint(messages)
# Out:
# [{'content': 'You are a helpful assistant.', 'role': 'system'},
#  {'content': 'Next week Im travel to Dubai', 'role': 'user'},
#  {'content': 'That sounds exciting! Do you need any tips or information about '
#              'traveling to Dubai? I can help with recommendations on places to '
#              'visit, things to do, weather, or travel advice.',
#   'role': 'assistant'}]

# %%
messages.append({"role": "user", "content": "where am I trarveling to next week?"})
pprint(messages)
# Out:
# [{'content': 'You are a helpful assistant.', 'role': 'system'},
#  {'content': 'Next week Im travel to Dubai', 'role': 'user'},
#  {'content': 'That sounds exciting! Do you need any tips or information about '
#              'traveling to Dubai? I can help with recommendations on places to '
#              'visit, things to do, weather, or travel advice.',
#   'role': 'assistant'},
#  {'content': 'where am I trarveling to next week?', 'role': 'user'}]

# %%
response = cleint.chat.completions.create(
    model="gpt-4.1-mini",    
    messages=messages
    
)


reply = response.choices[0].message.content
messages.append({"role": "assistant", "content": reply})
pprint(messages)
# Out:
# [{'content': 'You are a helpful assistant.', 'role': 'system'},
#  {'content': 'Next week Im travel to Dubai', 'role': 'user'},
#  {'content': 'That sounds exciting! Do you need any tips or information about '
#              'traveling to Dubai? I can help with recommendations on places to '
#              'visit, things to do, weather, or travel advice.',
#   'role': 'assistant'},
#  {'content': 'where am I trarveling to next week?', 'role': 'user'},
#  {'content': 'You mentioned that you are traveling to Dubai next week. Safe '
#              'travels! If you need any help preparing for your trip, feel free '
#              'to ask.',
#   'role': 'assistant'}]

# %%
messages.append({"role": "user", "content": "what is the capital??"})
pprint(messages)
# Out:
# [{'content': 'You are a helpful assistant.', 'role': 'system'},
#  {'content': 'Next week Im travel to Dubai', 'role': 'user'},
#  {'content': 'That sounds exciting! Do you need any tips or information about '
#              'traveling to Dubai? I can help with recommendations on places to '
#              'visit, things to do, weather, or travel advice.',
#   'role': 'assistant'},
#  {'content': 'where am I trarveling to next week?', 'role': 'user'},
#  {'content': 'You mentioned that you are traveling to Dubai next week. Safe '
#              'travels! If you need any help preparing for your trip, feel free '
#              'to ask.',
#   'role': 'assistant'},
#  {'content': 'what is the capital??', 'role': 'user'}]

# %%
response = cleint.chat.completions.create(
    model="gpt-4.1-mini",    
    messages=messages
    
)


reply = response.choices[0].message.content
messages.append({"role": "assistant", "content": reply})
pprint(messages)
#display(Markdown(reply))
# Out:
# [{'content': 'You are a helpful assistant.', 'role': 'system'},
#  {'content': 'Next week Im travel to Dubai', 'role': 'user'},
#  {'content': 'That sounds exciting! Do you need any tips or information about '
#              'traveling to Dubai? I can help with recommendations on places to '
#              'visit, things to do, weather, or travel advice.',
#   'role': 'assistant'},
#  {'content': 'where am I trarveling to next week?', 'role': 'user'},
#  {'content': 'You mentioned that you are traveling to Dubai next week. Safe '
#              'travels! If you need any help preparing for your trip, feel free '
#              'to ask.',
#   'role': 'assistant'},
#  {'content': 'what is the capital??', 'role': 'user'},
#  {'content': 'The capital of the United Arab Emirates (UAE), where Dubai is '
#              'located, is Abu Dhabi. If you want to know more about Dubai or '
#              'Abu Dhabi, just let me know!',
#   'role': 'assistant'}]
