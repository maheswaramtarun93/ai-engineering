# %% [markdown]
# ### Step 1: Import Libraries and Load the environment Variables

# %%
import os
from openai import OpenAI
from dotenv import load_dotenv

# %%
load_dotenv

OPENAI_API_KEY=os.getenv("OPENAI_API_KEY")

if OPENAI_API_KEY is None:
    raise Exception("API Key is missing")
else:
    print(OPENAI_API_KEY[:8])
# Out:
# sk-proj-

# %% [markdown]
# ### Step 2: Call the API

# %%
cleint = OpenAI()

response = cleint.chat.completions.create(
    model="gpt-4.1-mini",
    messages=[
        {"role": "user", "content": "tell me something about Jaswant singh khalra"}
        
    ]   
)
answer = response.choices[0].message.content

print(answer)
# Out:
# Jaswant Singh Khalra was a prominent human rights activist from Punjab, India, known for his courageous work in exposing the illegal extrajudicial killings and disappearances carried out by the Punjab police during the insurgency period in the 1980s and early 1990s. He meticulously documented evidence of thousands of cases where individuals were allegedly killed in fake encounters and their bodies secretly cremated or disposed of to cover up the abuses.
#
# Khalra's investigation revealed that the Punjab police had disposed of the remains of over 25,000 people, many of whom were innocent civilians. His activism brought significant attention to the human rights violations occurring during the counter-insurgency operations in Punjab.
#
# Tragically, Jaswant Singh Khalra was abducted and murdered in 1995, a crime for which members of the Punjab police were later held accountable in court. He is remembered as a symbol of bravery and commitment to justice and human rights in India.
